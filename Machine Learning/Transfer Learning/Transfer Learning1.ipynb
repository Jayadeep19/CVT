# %% [markdown]
# Transfer Learning using VGG16 Pre trained Model

# %% [markdown]
# Using a pre trained VGG16 model on Imagenet dataset, to classify the given input image

# %%
from keras.applications.vgg16 import VGG16
import tensorflow.keras.utils
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications.imagenet_utils import decode_predictions

# %%
from matplotlib import pyplot as plt
import cv2 as cv
import numpy as np

# %%
model = VGG16()
# Out:
# ...
# 553476096/553467096 [==============================] - 6s 0us/step

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
image1 = tensorflow.keras.utils.load_img('/content/drive/MyDrive/datasets/dog.2175.jpg', target_size = (224,224))
plt.imshow(image1)
image1 = tensorflow.keras.utils.img_to_array(image1)
image1 = image1.reshape((1, image1.shape[0], image1.shape[1], image1.shape[2]))
image1 = preprocess_input(image1)

# %%
predict1 = model.predict(image1)  
class_predicted = decode_predictions(predict1, top =5)
print(class_predicted)
print(len(class_predicted))
# Out:
# [[('n02091134', 'whippet', 0.47017398), ('n02109047', 'Great_Dane', 0.38891384), ('n02091831', 'Saluki', 0.026607135), ('n02100236', 'German_short-haired_pointer', 0.026455322), ('n02091032', 'Italian_greyhound', 0.012595053)]]
# 1

# %%
label = class_predicted[0][1]
print(label)
print(label[1])
# Out:
# ('n02109047', 'Great_Dane', 0.38891384)
# Great_Dane

# %%
list = []
for i in range (4):
  print('The top {} classification result is:'.format(i+1))
  print('{0} with probability of {1}%'.format(class_predicted[0][i][1], class_predicted[0][i][2]*100))
# Out:
# The top 1 classification result is:
# whippet with probability of 47.01739847660065%
# The top 2 classification result is:
# Great_Dane with probability of 38.89138400554657%
# The top 3 classification result is:
# Saluki with probability of 2.660713531076908%
# The top 4 classification result is:
# German_short-haired_pointer with probability of 2.645532228052616%
